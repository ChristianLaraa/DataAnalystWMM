# %%
import pandas as pd


data=pd.read_csv('data.csv')
data.head()
# Out:
#    id  ¿Cuántos años tienes?  ¿Cuál es tu género? ¿Cuál es tu estado civil?  \
# 0   1                     17                  0.0                   Soltero
# 1   2                     18                  1.0                   Soltero
# 2   3                     18                  0.0                   Soltero
# 3   4                     18                  0.0                   Soltero
# 4   5                     19                  0.0                   Soltero
#
#   Localidad de residencia (Alcaldía o Municipio)  \
# 0                                Nicolás Romero
# 1                               Ciudad de México
# 2                                      Coyoacan
# 3                                       Coyoacan
# 4                            Ecatepec de Morelos
#
#   ¿Cuál es tu último nivel educativo?  \
# 0               Preparatoria Completa
# 1               Preparatoria Completa
# 2             Licenciatura Incompleta
# 3               Preparatoria Completa
# ...
